# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.rcParams['figure.figsize'] = (16,9)

X, y = make_blobs(n_samples=800, n_features=3, centers=4)

# %%
X
# Out:
# array([[-5.46209265, -5.2302195 ,  8.77419934],
#        [-1.09567218, -1.78858942,  8.00583253],
#        [-5.70829464, -5.77822658,  8.93257832],
#        ...,
#        [-2.02971805,  6.87153386,  1.56552721],
#        [-4.78793669, -3.40172215,  6.8230399 ],
#        [ 6.02195591,  8.72923899, -5.92976172]])

# %%
from sklearn.cluster import KMeans
wcss_list = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    wcss_list.append(kmeans.inertia_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
plt.plot(range(1,11),wcss_list)
plt.title('the elbow methos')
plt.xlabel('number of clusters')
plt.ylabel('wcss_list')
plt.show()
